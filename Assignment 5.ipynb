# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_path = "low_contrast_image.jpg" 
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize=(10,4))
plt.imshow(img, cmap='gray')
plt.title("Original Low Contrast Image")
plt.axis('off')
plt.show()

# %%
min_val = np.min(img)
max_val = np.max(img)
stretched = ((img - min_val) / (max_val - min_val)) * 255
stretched = stretched.astype(np.uint8)
fig, axes = plt.subplots(2, 2, figsize=(12,6))
axes[0,0].imshow(img, cmap='gray')
axes[0,0].set_title("Original Image")
axes[0,0].axis('off')
axes[0,1].hist(img.ravel(), bins=256, range=(0,256), color='blue')
axes[0,1].set_title("Original Histogram")
axes[1,0].imshow(stretched, cmap='gray')
axes[1,0].set_title("Contrast Stretched Image")
axes[1,0].axis('off')
axes[1,1].hist(stretched.ravel(), bins=256, range=(0,256), color='blue')
axes[1,1].set_title("Stretched Histogram")
plt.tight_layout()
plt.show()

# %%
equalized = cv2.equalizeHist(img)
fig, axes = plt.subplots(2, 2, figsize=(12,6))
axes[0,0].imshow(img, cmap='gray')
axes[0,0].set_title("Original Image")
axes[0,0].axis('off')
axes[0,1].hist(img.ravel(), bins=256, range=(0,256), color='green')
axes[0,1].set_title("Original Histogram")
axes[1,0].imshow(equalized, cmap='gray')
axes[1,0].set_title("Histogram Equalized Image")
axes[1,0].axis('off')
axes[1,1].hist(equalized.ravel(), bins=256, range=(0,256), color='green')
axes[1,1].set_title("Equalized Histogram")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,5))
axes[0].imshow(img, cmap='gray')
axes[0].set_title("Original")
axes[0].axis('off')
axes[1].imshow(stretched, cmap='gray')
axes[1].set_title("Contrast Stretched")
axes[1].axis('off')
axes[2].imshow(equalized, cmap='gray')
axes[2].set_title("Histogram Equalized")
axes[2].axis('off')
plt.tight_layout()
plt.show()
